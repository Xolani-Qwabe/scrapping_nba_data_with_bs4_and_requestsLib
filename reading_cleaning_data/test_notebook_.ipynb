# %%
import pandas as pd

# %%
df = pd.read_csv('./advanced_player_sorted_csv/A.J. Green_data.csv')

# %%
df
# Out:
#     Unnamed: 0    Starters     MP    TS%   eFG%   3PAr    FTr  ORB%  DRB%  \
# 0            9  A.J. Green   8:38  0.000  0.000  0.000  0.000  16.8   0.0
# 1           12  A.J. Green   5:37  1.434  1.500  1.000  0.500   0.0  21.4
# 2           13  A.J. Green   8:34  0.699  0.667  0.833  0.167   0.0  23.3
# 3            9  A.J. Green   2:59    NaN    NaN    NaN    NaN   NaN   NaN
# 4           12  A.J. Green    0:0  0.000  0.000  0.000  0.000   0.0   0.0
# 5           11  A.J. Green   0:42  0.000  0.000  0.000  0.000   0.0   0.0
# 6           12  A.J. Green    0:0  0.000  0.000  0.000  0.000   0.0   0.0
# 7            9  A.J. Green  11:09  0.800  0.800  0.800  0.000   0.0   0.0
# 8            7  A.J. Green  19:53  0.750  0.750  1.000  0.000   7.1   0.0
# 9           12  A.J. Green    0:0  0.000  0.000  0.000  0.000   0.0   0.0
# 10          12  A.J. Green    0:0  0.000  0.000  0.000  0.000   0.0   0.0
# 11          12  A.J. Green   0:17  0.000  0.000  0.000  0.000   0.0   0.0
# ...
