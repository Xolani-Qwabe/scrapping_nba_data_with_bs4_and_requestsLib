# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://www.basketball-reference.com/leagues/NBA_2024_games.html'
data_source = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
page = BeautifulSoup(data_source.content, 'html.parser')

# %%
table_body = page.find_all('a')

# %%
table_body
# Out:
# [<a href="https://www.sports-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav"><svg height="15px" width="20px"><use xlink:href="#ic-sr-pennant"></use></svg> Sports Reference ®</a>,
#  <a href="https://www.baseball-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav">Baseball</a>,
#  <a href="https://www.pro-football-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav">Football</a>,
#  <a href="https://www.sports-reference.com/cfb/">(college)</a>,
#  <a href="https://www.basketball-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav">Basketball</a>,
#  <a href="https://www.sports-reference.com/cbb/">(college)</a>,
#  <a href="https://www.hockey-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav">Hockey</a>,
# ...

# %%
a_elements = page.find_all('a', href=lambda href:href.endswith('.html') and href.startswith('/boxscores'))

# Iterate over the found elements and print their href attributes
oct_box_scores = [a_element.get('href') for a_element in a_elements]

# %%
oct_box_scores
# Out:
# ['/boxscores/202310240DEN.html',
#  '/boxscores/202310240GSW.html',
#  '/boxscores/202310250ORL.html',
#  '/boxscores/202310250NYK.html',
#  '/boxscores/202310250IND.html',
#  '/boxscores/202310250CHO.html',
#  '/boxscores/202310250MIA.html',
#  '/boxscores/202310250TOR.html',
#  '/boxscores/202310250BRK.html',
#  '/boxscores/202310250MEM.html',
#  '/boxscores/202310250CHI.html',
#  '/boxscores/202310250UTA.html',
#  '/boxscores/202310250SAS.html',
#  '/boxscores/202310250LAC.html',
#  '/boxscores/202310260MIL.html',
#  '/boxscores/202310260LAL.html',
#  '/boxscores/202310270MEM.html',
#  '/boxscores/202310270CHO.html',
#  '/boxscores/202310270ATL.html',
#  '/boxscores/202310270CLE.html',
#  '/boxscores/202310270BOS.html',
#  '/boxscores/202310270CHI.html',
#  '/boxscores/202310270SAS.html',
#  '/boxscores/202310270DAL.html',
#  '/boxscores/202310270UTA.html',
#  '/boxscores/202310270POR.html',
#  '/boxscores/202310270SAC.html',
#  '/boxscores/202310280DET.html',
# ...
